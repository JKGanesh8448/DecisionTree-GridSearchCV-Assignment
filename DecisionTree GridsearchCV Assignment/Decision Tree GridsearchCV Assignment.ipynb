# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Insurance_Data.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor 
param_grid = {'criterion':['mse','absolute_error','friedman_mse'],'max_features':['auto','sqrt','log2'],'splitter':['best','random']}

grid= GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3, n_jobs=-1)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'absolute_error', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
regressor=grid.cv_results_
print("R_score value for best parameter {}:".format(grid.param_grid))
# Out:
# R_score value for best parameter {'criterion': ['mse', 'absolute_error', 'friedman_mse'], 'max_features': ['auto', 'sqrt', 'log2'], 'splitter': ['best', 'random']}:

# %%
table=pd.DataFrame.from_dict(regressor)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011685      0.003263         0.009388        0.006014
# 1        0.018522      0.006177         0.006250        0.007654
# 2        0.012335      0.006176         0.006997        0.007175
# 3        0.008569      0.003767         0.002049        0.002932
# 4        0.009196      0.008933         0.003129        0.006259
# 5        0.011351      0.005432         0.003350        0.003644
# 6        0.034282      0.007112         0.011124        0.007589
# 7        0.035262      0.005852         0.001911        0.002733
# 8        0.026212      0.006673         0.001143        0.002032
# 9        0.027758      0.005205         0.001255        0.002511
# 10       0.024518      0.004764         0.006140        0.004977
# 11       0.019022      0.007161         0.003071        0.006143
# 12       0.007598      0.003929         0.006620        0.005105
# 13       0.006906      0.003259         0.003085        0.003159
# 14       0.002987      0.003710         0.010398        0.005804
# 15       0.006458      0.002559         0.004771        0.003432
# 16       0.004951      0.004259         0.007779        0.006919
# 17       0.007461      0.001816         0.003725        0.002485
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6   absolute_error               auto           best
# 7   absolute_error               auto         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.709686
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.704658
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.643005
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.722934
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.709140
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.627615
# 6   {'criterion': 'absolute_error', 'max_features'...           0.737618
# 7   {'criterion': 'absolute_error', 'max_features'...           0.656558
# 8   {'criterion': 'absolute_error', 'max_features'...           0.595410
# 9   {'criterion': 'absolute_error', 'max_features'...           0.790742
# 10  {'criterion': 'absolute_error', 'max_features'...           0.684937
# 11  {'criterion': 'absolute_error', 'max_features'...           0.783814
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.715820
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.732043
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.708871
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.707610
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.646242
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.778787
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.654089           0.730326           0.710881
# 1            0.597528           0.655248           0.666250
# 2            0.550194           0.726396           0.725177
# 3            0.541208           0.420342           0.590052
# 4            0.691115           0.713447           0.751291
# 5            0.540252           0.571495           0.618580
# 6            0.635454           0.718696           0.728013
# 7            0.629310           0.749819           0.721558
# 8            0.559484           0.569603           0.627961
# 9            0.665630           0.717107           0.682935
# 10           0.598732           0.601610           0.589505
# 11           0.550607           0.691682           0.647477
# 12           0.652431           0.721027           0.713980
# 13           0.682234           0.774806           0.720813
# 14           0.544512           0.708618           0.731745
# 15           0.580962           0.608568           0.624970
# 16           0.581246           0.784589           0.738026
# 17           0.604549           0.708431           0.667387
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.664423         0.693881        0.029388                7
# 1            0.677176         0.660172        0.035366               11
# 2            0.567648         0.642484        0.074830               14
# 3            0.671744         0.589256        0.105371               18
# 4            0.728298         0.718658        0.020170                2
# 5            0.619517         0.595492        0.033969               17
# 6            0.741071         0.712170        0.039145                3
# 7            0.717262         0.694901        0.044719                5
# 8            0.727703         0.616032        0.060649               16
# 9            0.662835         0.703850        0.047553                4
# 10           0.694368         0.633831        0.045851               15
# 11           0.713341         0.677384        0.077190               10
# 12           0.668803         0.694412        0.028170                6
# 13           0.758348         0.733649        0.031983                1
# 14           0.604741         0.659697        0.072512               12
# 15           0.723467         0.649115        0.056253               13
# 16           0.683935         0.686807        0.070685                8
# 17           0.631398         0.678110        0.061259                9

# %%
age_input=float(input("Age :"))
bmi_input=float(input("BMI :"))
children_input=float(input("Children: "))
sex_male_input=int(input("Sex: Male 0 or 1: "))
smoker_yes_input=int(input("Smoker Yes 0 or 1: "))
# Out:
# Age :32
# BMI :43
# Children: 2
# Sex: Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid
Future_Prediction([[ 'age_input', 'bmi_input', 'children_input', 'sex_male_input', 'smoker_yes_input']])
    

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-993c4c2df042> in <module>
#       1 Future_Prediction=grid
# ----> 2 Future_Prediction([[ 'age_input', 'bmi_input', 'children_input', 'sex_male_input', 'smoker_yes_input']])
#       3
#       4
#       5 print("Future_Prediction={}".format(Future_Prediction))
#
# TypeError: 'GridSearchCV' object is not callable
